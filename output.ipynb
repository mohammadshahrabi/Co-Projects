# %%
import pandas as pd
df= pd.read_csv('khotbeh_data.csv')
df
# Out:
#      تاریخ خطبه                                         عنوان خطبه  \
# 0      1403/9/9   1403/9/9تغییر شناخت مردم، نسبت به مدیریت سیاس...
# 1      1403/9/2   1403/9/2فرهنگ بسیج از مرزهای ایران عبور کرده است
# 2     1403/8/25   1403/8/25هر کس در مسیر ناامید کردن مردم حرکت ...
# 3     1403/8/18   1403/8/18از بزرگ‌ترین امتیازات سید مقاومت، ار...
# 4     1403/8/11   1403/8/11شعار مرگ بر آمریکا، راهبردی دقیق و ر...
# ..          ...                                                ...
# 289   1397/1/10   1397/1/10حمایت از کالای ایرانی باید همه‌جانبه...
# 290    1397/1/3   1397/1/3بهره‌گیری از نیروی جوان، شرط رسیدن به...
# 291    1394/8/1                                           1394/8/1
# 292   1394/6/13   1394/6/13پیام رزمایش اقتدار ثارالله این است ک...
# 293    1394/6/6   1394/6/6مردم انقلابی ایران از شورای نگهبان حم...
#
#                 نام امام جمعه  \
# 0    سیدمحمدمهدی حسینی همدانی
# 1    سیدمحمدمهدی حسینی همدانی
# 2    سیدمحمدمهدی حسینی همدانی
# 3    سیدمحمدمهدی حسینی همدانی
# ...

# %%
print('fatemeh')
# Out:
# fatemeh
